# %% [markdown]
# # SETUP

# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from sqlalchemy import URL

from dbhelpers.config import build_config
from dbhelpers.db import get_db, test_connection, get_db_url

# %%
pd.options.display.width = 200

# %% [markdown]
# ## DB CONFIG

# %%
DB_NAME = 'testing'
CACHE_TTL = None
config = build_config(database=DB_NAME)
config
# Out:
# {'host': 'localhost',
#  'user': 'root',
#  'password': '10010',
#  'database': 'testing'}

# %% [markdown]
# # FUNCTIONS

# %% [markdown]
# ## get_winners()

# %%
def get_winners() -> pd.DataFrame:
    db_url = get_db_url(**config)
    engine = create_engine(db_url)
    sql = 'select * from lotteria'
    params = ()
    df =  pd.read_sql(sql, engine, params=tuple(params), index_col='index')
    return df

# %% [markdown]
# ## split_df()

# %%
def split_df(df:pd.DataFrame, rows:int) -> list[pd.DataFrame]:
    splitdf = [df.iloc[i: i+rows -1, :] for i in range(
                0, len(df), rows)
    ]
    
    return splitdf

# %% [markdown]
# # START
# ## get data

# %%
winners = get_winners()
winners.head()
# Out:
#        categoria serie  numero     luogo prov   premio
# index
# 0              1     T  173756  SOMAGLIA   LO  5000000
# 1              1     T  378442    PESARO   PU  2500000
# 2              1     G  330068   PALERMO   PA  2000000
# 3              1     G  173817    TORINO   TO  1500000
# 4              1     S  185025      DOLO   VE  1000000

# %% [markdown]
# ## split_df
# ### no sort, filter

# %%
total_split = split_df(winners, 10)
total_split[0]
# Out:
#        categoria serie  numero                                      luogo prov   premio
# index
# 0              1     T  173756                                   SOMAGLIA   LO  5000000
# 1              1     T  378442                                     PESARO   PU  2500000
# 2              1     G  330068                                    PALERMO   PA  2000000
# 3              1     G  173817                                     TORINO   TO  1500000
# 4              1     S  185025                                       DOLO   VE  1000000
# 5              2     S  030585  DISTRIBUTORE LOCALE MONTENERO DI BISACCIA   CB   100000
# 6              2     C  439458                                   AVELLINO   AV   100000
# 7              2     M  217442                                   MASSAFRA   TA   100000
# 8              2     D  138065                                    FOLIGNO   PG   100000

# %%
len(total_split)
# Out:
# 28

# %%
total_split[-1]
# Out:
#        categoria serie  numero                     luogo prov  premio
# index
# 270            4     B  189342                   MESAGNE   BR   20000
# 271            4     Q   44926  DISTRIBUTORE LOCALE ROMA   RM   20000
# 272            4     N  445610            SALA CONSILINA   SA   20000
# 273            4     G  394402                 BUSSOLENO   TO   20000
# 274            4     M  479982    CASTIGLIONE DEI PEPOLI   BO   20000
# 275            4     N  342401                    TORINO   TO   20000
# 276            4     M   41952  DISTRIBUTORE LOCALE ROMA   RM   20000
# 277            4     T  404382                      ROMA   RM   20000
# 278            4     Q  270923                  BAGHERIA   PA   20000

# %% [markdown]
# ### sort, no filter

# %%
sorted_split = split_df(
        winners.sort_values(by='categoria'), 
        10
)
sorted_split[0].head()
# Out:
#        categoria serie  numero     luogo prov   premio
# index
# 0              1     T  173756  SOMAGLIA   LO  5000000
# 1              1     T  378442    PESARO   PU  2500000
# 2              1     G  330068   PALERMO   PA  2000000
# 3              1     G  173817    TORINO   TO  1500000
# 4              1     S  185025      DOLO   VE  1000000

# %% [markdown]
# # the problem

# %%
ts0 = total_split[0]
ts1 = total_split[1]
ss0 = sorted_split[0]
ss1 = sorted_split[1]   # empty

# %% [markdown]
# # DEBUG

# %%
# splitdf = [df.loc[i: i+rows -1, :] for i in range(
#             0, len(df), rows)
# ]

rows = 10
indexes = [i for i in range(0, len(winners), rows)]
# print(indexes)

chunks = [(i, i+rows-1) for i in indexes]
# print(chunks)

print(chunks)
# Out:
# [(0, 9), (10, 19), (20, 29), (30, 39), (40, 49), (50, 59), (60, 69), (70, 79), (80, 89), (90, 99), (100, 109), (110, 119), (120, 129), (130, 139), (140, 149), (150, 159), (160, 169), (170, 179), (180, 189), (190, 199), (200, 209), (210, 219), (220, 229), (230, 239), (240, 249), (250, 259), (260, 269), (270, 279)]

# %%
source = winners
# source = winners.sort_values(by='categoria', ignore_index=False)

for i, i1 in chunks:
    tempdf = source.iloc[i:i1]
    print(tempdf.head(2))
    print('-' * 80)
# Out:
#        categoria serie  numero     luogo prov   premio
# index
# 0              1     T  173756  SOMAGLIA   LO  5000000
# 1              1     T  378442    PESARO   PU  2500000
# --------------------------------------------------------------------------------
#        categoria serie  numero   luogo prov  premio
# index
# 10             2     Q  330398  FOGGIA   FG  100000
# 11             2     L  320913  ISPICA   RG  100000
# --------------------------------------------------------------------------------
#        categoria serie  numero      luogo prov  premio
# index
# 20             2     Q  311109  VIDIGULFO   PV  100000
# 21             2     O  115657     CERVIA   RA  100000
# --------------------------------------------------------------------------------
#        categoria serie  numero                                 luogo prov  premio
# index
# 30             3     A  151684  DISTRIBUTORE LOCALE SESTO FIORENTINO   FI   50000
# 31             3     C  044674         DISTRIBUTORE LOCALE FROSINONE   FR   50000
# --------------------------------------------------------------------------------
#        categoria serie  numero    luogo prov  premio
# index
# 40             3     D  119183  BOLOGNA   BO   50000
# 41             3     A  467555   MODENA   MO   50000
# --------------------------------------------------------------------------------
#        categoria serie  numero                        luogo prov  premio
# index
# 50             3     B  044418  DISTRIBUTORE LOCALE BERCETO   PR   50000
# 51             3     D  400957          GALLICANO NEL LAZIO   RM   50000
# --------------------------------------------------------------------------------
#        categoria serie  numero             luogo prov  premio
# index
# 60             3     R  396533  LONATO DEL GARDA   BS   50000
# 61             3     I  309460            MILANO   MI   50000
# --------------------------------------------------------------------------------
#        categoria serie  numero    luogo prov  premio
# index
# 70             3     M  325384  SCAFATI   SA   50000
# 71             3     E  290218    IMOLA   BO   50000
# --------------------------------------------------------------------------------
#        categoria serie  numero               luogo prov  premio
# index
# 80             4     P  393145  CORIGLIANO ROSSANO   CS   20000
# 81             4     B  341438              GENOVA   GE   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                     luogo prov  premio
# index
# 90             4     I  007690  DISTRIBUTORE LOCALE ROMA   RM   20000
# 91             4     C  120643                  CRISPANO   NA   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero     luogo prov  premio
# index
# 100            4     M  355049    TORINO   TO   20000
# 101            4     L  439043  RICCIONE   RN   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero   luogo prov  premio
# index
# 110            4     A  205419   TEANO   CE   20000
# 111            4     D  459766  MILANO   MI   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero         luogo prov  premio
# index
# 120            4     I  114969     SCISCIANO   NA   20000
# 121            4     F  145263  NOCERA UMBRA   PG   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero               luogo prov  premio
# index
# 130            4     T  150563            TAORMINA   ME   20000
# 131            4     T  218243  CASTIONE ANDEVENNO   SO   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                luogo prov  premio
# index
# 140            4     T  336904  GUIDONIA MONTECELIO   RM   20000
# 141            4     R  211535                 ROMA   RM   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero              luogo prov  premio
# index
# 150            4     R  296645  SAN VITTORE OLONA   MI   20000
# 151            4     T  293112             MILANO   MI   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero    luogo prov  premio
# index
# 160            4     Q  268826  SIMAXIS   OR   20000
# 161            4     I  159032   ANAGNI   FR   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                        luogo prov  premio
# index
# 170            4     D  447435                 ZOLA PREDOSA   BO   20000
# 171            4     O   91106  DISTRIBUTORE LOCALE LEGNANO   MI   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero      luogo prov  premio
# index
# 180            4     Q  401091      LUCCA   LU   20000
# 181            4     O  389452  BOTTICINO   BS   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero      luogo prov  premio
# index
# 190            4     D  463722  COMACCHIO   FE   20000
# 191            4     P  450622     MODENA   MO   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                   luogo prov  premio
# index
# 200            4     F  447517                   CURTI   CE   20000
# 201            4     A  367279  SAN MARTINO SICCOMARIO   PV   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                 luogo prov  premio
# index
# 210            4     L  176197  ROSETO DEGLI ABRUZZI   TE   20000
# 211            4     B  331751    TORRICELLA VERZATE   PV   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero       luogo prov  premio
# index
# 220            4     G  284386      GUBBIO   PG   20000
# 221            4     G  151078  RONDISSONE   TO   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero luogo prov  premio
# index
# 230            4     P  245541  ENNA   EN   20000
# 231            4     S  238989  ROMA   RM   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero               luogo prov  premio
# index
# 240            4    AA   15256  RIVENDITORE ONLINE  NAN   20000
# 241            4     D  242142              MILANO   MI   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                     luogo prov  premio
# index
# 250            4     M  290067                      ROMA   RM   20000
# 251            4     D   98128  DISTRIBUTORE LOCALE ROMA   RM   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero           luogo prov  premio
# index
# 260            4     I  347822         PESCARA   PE   20000
# 261            4     A  270577  MOGGIO UDINESE   UD   20000
# --------------------------------------------------------------------------------
#        categoria serie  numero                     luogo prov  premio
# index
# 270            4     B  189342                   MESAGNE   BR   20000
# 271            4     Q   44926  DISTRIBUTORE LOCALE ROMA   RM   20000
# --------------------------------------------------------------------------------

# %%
pages = [source.iloc[i:i1, :] for i, i1 in chunks]
for page in pages:
    print(page.head(2))
# Out:
#        categoria serie  numero     luogo prov   premio
# index
# 0              1     T  173756  SOMAGLIA   LO  5000000
# 1              1     T  378442    PESARO   PU  2500000
#        categoria serie  numero   luogo prov  premio
# index
# 10             2     Q  330398  FOGGIA   FG  100000
# 11             2     L  320913  ISPICA   RG  100000
#        categoria serie  numero      luogo prov  premio
# index
# 20             2     Q  311109  VIDIGULFO   PV  100000
# 21             2     O  115657     CERVIA   RA  100000
#        categoria serie  numero                                 luogo prov  premio
# index
# 30             3     A  151684  DISTRIBUTORE LOCALE SESTO FIORENTINO   FI   50000
# 31             3     C  044674         DISTRIBUTORE LOCALE FROSINONE   FR   50000
#        categoria serie  numero    luogo prov  premio
# index
# 40             3     D  119183  BOLOGNA   BO   50000
# 41             3     A  467555   MODENA   MO   50000
#        categoria serie  numero                        luogo prov  premio
# index
# 50             3     B  044418  DISTRIBUTORE LOCALE BERCETO   PR   50000
# 51             3     D  400957          GALLICANO NEL LAZIO   RM   50000
#        categoria serie  numero             luogo prov  premio
# index
# 60             3     R  396533  LONATO DEL GARDA   BS   50000
# 61             3     I  309460            MILANO   MI   50000
#        categoria serie  numero    luogo prov  premio
# index
# 70             3     M  325384  SCAFATI   SA   50000
# 71             3     E  290218    IMOLA   BO   50000
#        categoria serie  numero               luogo prov  premio
# index
# 80             4     P  393145  CORIGLIANO ROSSANO   CS   20000
# 81             4     B  341438              GENOVA   GE   20000
#        categoria serie  numero                     luogo prov  premio
# index
# 90             4     I  007690  DISTRIBUTORE LOCALE ROMA   RM   20000
# 91             4     C  120643                  CRISPANO   NA   20000
#        categoria serie  numero     luogo prov  premio
# index
# 100            4     M  355049    TORINO   TO   20000
# 101            4     L  439043  RICCIONE   RN   20000
#        categoria serie  numero   luogo prov  premio
# index
# 110            4     A  205419   TEANO   CE   20000
# 111            4     D  459766  MILANO   MI   20000
#        categoria serie  numero         luogo prov  premio
# index
# 120            4     I  114969     SCISCIANO   NA   20000
# 121            4     F  145263  NOCERA UMBRA   PG   20000
#        categoria serie  numero               luogo prov  premio
# index
# 130            4     T  150563            TAORMINA   ME   20000
# 131            4     T  218243  CASTIONE ANDEVENNO   SO   20000
#        categoria serie  numero                luogo prov  premio
# index
# 140            4     T  336904  GUIDONIA MONTECELIO   RM   20000
# 141            4     R  211535                 ROMA   RM   20000
#        categoria serie  numero              luogo prov  premio
# index
# 150            4     R  296645  SAN VITTORE OLONA   MI   20000
# 151            4     T  293112             MILANO   MI   20000
#        categoria serie  numero    luogo prov  premio
# index
# 160            4     Q  268826  SIMAXIS   OR   20000
# 161            4     I  159032   ANAGNI   FR   20000
#        categoria serie  numero                        luogo prov  premio
# index
# 170            4     D  447435                 ZOLA PREDOSA   BO   20000
# 171            4     O   91106  DISTRIBUTORE LOCALE LEGNANO   MI   20000
#        categoria serie  numero      luogo prov  premio
# index
# 180            4     Q  401091      LUCCA   LU   20000
# 181            4     O  389452  BOTTICINO   BS   20000
#        categoria serie  numero      luogo prov  premio
# index
# 190            4     D  463722  COMACCHIO   FE   20000
# 191            4     P  450622     MODENA   MO   20000
#        categoria serie  numero                   luogo prov  premio
# index
# 200            4     F  447517                   CURTI   CE   20000
# 201            4     A  367279  SAN MARTINO SICCOMARIO   PV   20000
#        categoria serie  numero                 luogo prov  premio
# index
# 210            4     L  176197  ROSETO DEGLI ABRUZZI   TE   20000
# 211            4     B  331751    TORRICELLA VERZATE   PV   20000
#        categoria serie  numero       luogo prov  premio
# index
# 220            4     G  284386      GUBBIO   PG   20000
# 221            4     G  151078  RONDISSONE   TO   20000
#        categoria serie  numero luogo prov  premio
# index
# 230            4     P  245541  ENNA   EN   20000
# 231            4     S  238989  ROMA   RM   20000
#        categoria serie  numero               luogo prov  premio
# index
# 240            4    AA   15256  RIVENDITORE ONLINE  NAN   20000
# 241            4     D  242142              MILANO   MI   20000
#        categoria serie  numero                     luogo prov  premio
# index
# 250            4     M  290067                      ROMA   RM   20000
# 251            4     D   98128  DISTRIBUTORE LOCALE ROMA   RM   20000
#        categoria serie  numero           luogo prov  premio
# index
# 260            4     I  347822         PESCARA   PE   20000
# 261            4     A  270577  MOGGIO UDINESE   UD   20000
#        categoria serie  numero                     luogo prov  premio
# index
# 270            4     B  189342                   MESAGNE   BR   20000
# 271            4     Q   44926  DISTRIBUTORE LOCALE ROMA   RM   20000

# %%
pages[1]
# Out:
#        categoria serie  numero                                 luogo prov  premio
# index
# 10             2     Q  330398                                FOGGIA   FG  100000
# 11             2     L  320913                                ISPICA   RG  100000
# 12             2     D  052288  DISTRIBUTORE LOCALE GREVE IN CHIANTI   FI  100000
# 13             2     I  265285                                  ROMA   RM  100000
# 14             2     B  431066                                SPINEA   VE  100000
# 15             2     B  475642                                OMEGNA   VB  100000
# 16             2     I  479949                         MONTEPULCIANO   SI  100000
# 17             2     I  336915                                 IVREA   TO  100000
# 18             2     E  322777                            BORGOSESIA   VC  100000

# %%
# df = winners
df = winners.sort_values(by='categoria')

rows = 10
indexes = [i for i in range(0, len(winners), rows)]
# print(indexes)

chunks = [(i, i+rows-1) for i in indexes]
# print(chunks)


splitdf = [df.loc[i: i1] for i, i1 in chunks
]
splitdf[1]
# Out:
# Empty DataFrame
# Columns: [categoria, serie, numero, luogo, prov, premio]
# Index: []

# %%
df = winners.sort_values(by='categoria')
# df = winners
df
# Out:
#        categoria serie  numero                         luogo prov   premio
# index
# 0              1     T  173756                      SOMAGLIA   LO  5000000
# 1              1     T  378442                        PESARO   PU  2500000
# 2              1     G  330068                       PALERMO   PA  2000000
# 3              1     G  173817                        TORINO   TO  1500000
# 4              1     S  185025                          DOLO   VE  1000000
# ...          ...   ...     ...                           ...  ...      ...
# 149            4     R   12826      DISTRIBUTORE LOCALE ROMA   RM    20000
# 150            4     R  296645             SAN VITTORE OLONA   MI    20000
# 151            4     T  293112                        MILANO   MI    20000
# 141            4     R  211535                          ROMA   RM    20000
# 279            4     P    7303  DISTRIBUTORE LOCALE MONDOLFO   PU    20000
#
# [280 rows x 6 columns]

# %%
rows = 10
indexes = [i for i in range(0, len(winners), rows)]
chunks = [(i, i+rows-1) for i in indexes]

pages = []
for i, i1 in chunks:
    pages.append(
        (
            i, i1,
            df.iloc[i: i1]
        )
        
    )

pages[0]
# Out:
# (0,
#  9,
#         categoria serie  numero       luogo prov   premio
#  index
#  0              1     T  173756    SOMAGLIA   LO  5000000
#  1              1     T  378442      PESARO   PU  2500000
#  2              1     G  330068     PALERMO   PA  2000000
#  3              1     G  173817      TORINO   TO  1500000
#  4              1     S  185025        DOLO   VE  1000000
#  19             2     I  336889  VALMADRERA   LC   100000
#  20             2     Q  311109   VIDIGULFO   PV   100000
#  21             2     O  115657      CERVIA   RA   100000
#  22             2     I  459455    SORRENTO   NA   100000)

# %%
df.iloc[0:9]
# Out:
#        categoria serie  numero       luogo prov   premio
# index
# 0              1     T  173756    SOMAGLIA   LO  5000000
# 1              1     T  378442      PESARO   PU  2500000
# 2              1     G  330068     PALERMO   PA  2000000
# 3              1     G  173817      TORINO   TO  1500000
# 4              1     S  185025        DOLO   VE  1000000
# 19             2     I  336889  VALMADRERA   LC   100000
# 20             2     Q  311109   VIDIGULFO   PV   100000
# 21             2     O  115657      CERVIA   RA   100000
# 22             2     I  459455    SORRENTO   NA   100000
